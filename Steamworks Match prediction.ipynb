# %%
"""
Define our CalcOpr function and the Match class that we use to interface with it
"""

from collections import namedtuple
import numpy.matlib as mat
import numpy as np
from numpy.linalg import inv

Match = namedtuple("Match", ["teams", "score"])

def CalcOpr(matches):
    """
    Given a list of matches, to least squares OPR calculation
    """
    num_matches = len(matches) # rows
    teams = list(set().union(*[match.teams for match in matches]))
    num_teams = len(teams)
    
    alliances = mat.zeros((num_matches, num_teams))
    scores = mat.zeros((num_matches, 1))
    
    for idx, match in enumerate(matches):
        scores[idx, 0] = match.score
        for team in match.teams:
            alliances[idx, teams.index(team)] = 1
    
    least_squares_approx = np.dot(
        inv(np.dot(np.transpose(alliances), alliances)),
        np.dot(np.transpose(alliances), scores))
    
    oprs = {}
    for idx, team in enumerate(teams):
        oprs[team] = least_squares_approx[idx, 0] 
    return oprs

print(CalcOpr([
            Match(teams=['A', 'B'], score=10),
            Match(teams=['A', 'C'], score=13),
            Match(teams=['B', 'C'], score=7),
            Match(teams=['A', 'D'], score=15),
            Match(teams=['B', 'D'], score=10),
        ]))
# Out:
# {'C': 5.0, 'A': 7.7500000000000018, 'D': 7.4999999999999964, 'B': 2.25}

# %%
"""
Connect to the blue alliance api.  Also install a cache so that every request
we make is cached to a file for a day.  This doesn't respect the cache headers
and last-changed headers from tba's api, but since we're using old data we can
be pretty sure that the data we're using is fresh.
"""

import requests
import requests_cache

# Cache all api requests in a file called tba_cache.sqlite for a day
# (monkeypatch the requests module that tbapy uses)
requests_cache.install_cache(cache_name="tba_cache", expire_after=60 * 60 * 24)

import tbapy
from pprint import pprint

api_key = "6qOZ9uAEsb4CDrOBNG6ZnIdi9cWBaZ6DHnCSato97Qfo7bBeUwT9NfFt4Gi5sHFN"

tba = tbapy.TBA(api_key)
pprint(tba.status())
# Out:
# {'android': {'latest_app_version': 4020399, 'min_app_version': 4000299},
#  'contbuild_enabled': True,
#  'current_season': 2018,
#  'down_events': [],
#  'ios': {'latest_app_version': -1, 'min_app_version': -1},
#  'is_datafeed_down': False,
#  'json': {'android': {'latest_app_version': 4020399,
#                       'min_app_version': 4000299},
#           'contbuild_enabled': True,
#           'current_season': 2018,
#           'down_events': [],
#           'ios': {'latest_app_version': -1, 'min_app_version': -1},
#           'is_datafeed_down': False,
#           'max_season': 2018,
#           'web': {'commit_time': '2018-02-09 14:37:30 -0500',
#                   'current_commit': '3dd2c80b8ec53047bdef65b60929b6293b9e98a6',
#                   'deploy_time': 'Fri Feb  9 19:51:54 UTC 2018',
#                   'travis_job': '339614111'}},
#  'max_season': 2018,
#  'web': {'commit_time': '2018-02-09 14:37:30 -0500',
#          'current_commit': '3dd2c80b8ec53047bdef65b60929b6293b9e98a6',
#          'deploy_time': 'Fri Feb  9 19:51:54 UTC 2018',
#          'travis_job': '339614111'}}

# %%
"""
Given the matches from an event, let's calculate the OPR for each component.
Current components are raw score, rotor rp, and fuel rp.  
"""


def CalcScoreOpr(matches):
    """
    Takes in Matches (like what tba.event_matches returns) and outputs a dictionary
    mapping team-name to score opr
    """
    match_outcomes = []
    for match in matches:
        match_outcomes.append(
            Match(teams=match['alliances']['blue']['team_keys'],
                  score=match['alliances']['blue']['score'])
        )
        match_outcomes.append(
            Match(teams=match['alliances']['red']['team_keys'],
                  score=match['alliances']['red']['score'])
        )
    return CalcOpr(match_outcomes)


def CalcRotorRpOpr(matches):
    """
    Calculate each team's opr with respect to getting a robot bonus.  Rotor bonus is
    pretty nonlinear so part of the experiment here is seeing how well we can predict
    an alliance's liklihood of getting the rotor RP
    """
    match_outcomes = []
    for match in matches:
        if match['comp_level'] == 'qm':
            match_outcomes.append(
                Match(teams=match['alliances']['blue']['team_keys'],
                      score=match['score_breakdown']['blue']['rotorRankingPointAchieved'])
            )
            match_outcomes.append(
                Match(teams=match['alliances']['red']['team_keys'],
                      score=match['score_breakdown']['red']['rotorRankingPointAchieved'])
            )
    return CalcOpr(match_outcomes)
    
    
def CalcFuelRpOpr(matches):
    """
    Calculate each team's opr with respect to getting a fuel bonus.  Fuel bonus
    is pretty nonlinear so part of the experiment here is seeing how well we can predict
    an alliance's likliood of getting the fuel RP
    """
    match_outcomes = []
    for match in matches:
        if match['comp_level'] == 'qm':
            match_outcomes.append(
                Match(teams=match['alliances']['blue']['team_keys'],
                      score=match['score_breakdown']['blue']['kPaRankingPointAchieved'])
            )
            match_outcomes.append(
                Match(teams=match['alliances']['red']['team_keys'],
                      score=match['score_breakdown']['red']['kPaRankingPointAchieved'])
            )
    return CalcOpr(match_outcomes)

# %%
from collections import namedtuple

EventSummary = namedtuple("EventSummary", ["team_score_opr", "team_rotor_rp_opr", "team_fuel_rp_opr"])

_event_stats = {}

def get_event_stats(event):
    if event not in _event_stats:
        event_matches = tba.event_matches(event)

        _event_stats[event] = EventSummary(
            team_score_opr = CalcScoreOpr(event_matches),
            team_rotor_rp_opr = CalcRotorRpOpr(event_matches),
            team_fuel_rp_opr = CalcFuelRpOpr(event_matches),
        )
    
    return _event_stats[event]
    
pprint(dict(get_event_stats("2017roe")._asdict()))
# Out:
# {'team_fuel_rp_opr': {'frc1002': 0.001306754014177812,
#                       'frc1011': -0.0066918194307006131,
#                       'frc115': -0.00027964533450868662,
#                       'frc1339': 0.027811071747965731,
#                       'frc1414': -0.028274925604767416,
#                       'frc1477': 0.03018638945970134,
#                       'frc1482': 0.0038428145423401554,
#                       'frc1574': 0.81224332275922373,
#                       'frc175': 0.0086009350495095775,
#                       'frc2183': 0.0017301384649544543,
#                       'frc2403': 0.097203821426750811,
#                       'frc2468': -0.00038628735476960163,
#                       'frc2478': 0.045443848842528778,
#                       'frc2485': -0.09162360885635755,
#                       'frc2642': 0.019303911285171352,
#                       'frc2655': 0.025380401944398685,
#                       'frc2881': 0.057278301432307173,
#                       'frc2905': -0.020735668480764115,
#                       'frc2928': 0.068849817876854402,
#                       'frc3140': 0.018086248484490114,
#                       'frc3158': -0.016657193255109507,
#                       'frc3229': -0.10267830550004625,
#                       'frc3316': 0.026762464924760809,
#                       'frc3402': -0.039483576172447271,
#                       'frc365': -0.02721767587111959,
#                       'frc3653': 0.0020891973125617917,
#                       'frc3824': 0.052404925962654364,
#                       'frc3826': -0.017794395891780664,
#                       'frc3834': -0.0090656566704005528,
#                       'frc3991': 0.018102864551197927,
#                       'frc4060': 0.0037161512777656655,
#                       'frc418': -0.046636978182303154,
#                       'frc4191': -0.0094456836703166753,
#                       'frc4219': 0.0025258143483291497,
#                       'frc4265': -0.022003758612856618,
#                       'frc4276': -0.029813971194339855,
#                       'frc435': 0.0023391021042055314,
#                       'frc4371': 0.0069991652715612543,
#                       'frc441': -0.016676661908804225,
#                       'frc4561': -0.0027243958883944003,
#                       'frc4590': 0.0090828977087668121,
#                       'frc4592': -0.048263946440215089,
#                       'frc4723': -0.0038860381201868844,
#                       'frc488': 0.30033399884176021,
#                       'frc5026': -0.018122832416601058,
#                       'frc5472': 0.022413876046679708,
#                       'frc5499': -0.008040908453964532,
#                       'frc5515': 0.016906886480131608,
#                       'frc5614': 0.012611883394193484,
#                       'frc5803': -0.0062227397318728624,
#                       'frc5816': 0.012826786882090577,
#                       'frc585': 0.0039384782963329586,
#                       'frc5970': -0.007602521366246541,
#                       'frc6144': 0.022399432771529209,
#                       'frc624': 0.070233039643396056,
#                       'frc6304': 0.011332485015927686,
#                       'frc6325': -0.0064434004094025797,
#                       'frc6361': 0.032255668828899589,
#                       'frc6388': -0.017603607162033692,
#                       'frc6409': -0.0075683972926656289,
#                       'frc6508': 0.029565915005615277,
#                       'frc6560': -0.11277016731226065,
#                       'frc6705': -0.075618988586681563,
#                       'frc8': 0.013333653904305243,
#                       'frc955': 0.0043140516565096688,
#                       'frc973': 0.90657723761236952},
#  'team_rotor_rp_opr': {'frc1002': 0.43938948374230818,
#                        'frc1011': 0.44738981279559908,
#                        'frc115': 0.52162574155050456,
#                        'frc1339': 0.11918285337011986,
#                        'frc1414': 0.19608876687377721,
#                        'frc1477': 0.25436618290144603,
#                        'frc1482': -0.25719106222682775,
#                        'frc1574': -0.056967800190967338,
#                        'frc175': -0.0053751933490292017,
#                        'frc2183': 0.13293113262902351,
#                        'frc2403': 0.28858680203501219,
#                        'frc2468': 0.32516347125974637,
#                        'frc2478': 0.11516523854076534,
#                        'frc2485': 0.18633297770871718,
#                        'frc2642': 0.59547439554897463,
#                        'frc2655': 0.0068842747009712144,
#                        'frc2881': -0.069810582909481902,
#                        'frc2905': -0.2939552335032064,
#                        'frc2928': 0.36803150559033987,
#                        'frc3140': 0.071272254123008791,
#                        'frc3158': 0.065940076322421312,
#                        'frc3229': 0.21508008727519684,
#                        'frc3316': 0.029927150499933584,
#                        'frc3402': 0.18384304097040832,
#                        'frc365': 0.32070475635413614,
#                        'frc3653': -0.017683464282050761,
#                        'frc3824': 0.20573614251929695,
#                        'frc3826': 0.088548088860694638,
#                        'frc3834': -0.085934757546402465,
#                        'frc3991': 0.14587466546015862,
#                        'frc4060': -0.038894353678011959,
#                        'frc418': -0.17970513216805417,
#                        'frc4191': -0.12337825277918447,
#                        'frc4219': -0.025709911015909106,
#                        'frc4265': 0.34617934360673164,
#                        'frc4276': 0.043668652706567342,
#                        'frc435': 0.16213623103641167,
#                        'frc4371': -0.0021389225305940298,
#                        'frc441': -0.074590184052536521,
#                        'frc4561': 0.32038989374946897,
#                        'frc4590': 0.067514031648745365,
#                        'frc4592': 0.077948991301704434,
#                        'frc4723': 0.048125839561365708,
#                        'frc488': 0.032471330519056499,
#                        'frc5026': -0.0098686377863713599,
#                        'frc5472': -0.30185379610970897,
#                        'frc5499': 0.081449917409418413,
#                        'frc5515': -0.0036499348849121354,
#                        'frc5614': 0.20351451221402839,
#                        'frc5803': 0.20076833329235635,
#                        'frc5816': 0.038132464539974334,
#                        'frc585': -0.02843050280458144,
#                        'frc5970': 0.37938371255542985,
#                        'frc6144': -0.038036927451709626,
#                        'frc624': 0.34057920836655797,
#                        'frc6304': -0.15973436723351769,
#                        'frc6325': 0.18836827178521109,
#                        'frc6361': 0.066320312931662712,
#                        'frc6388': -0.1941406489043401,
#                        'frc6409': -0.27390216394899847,
#                        'frc6508': 0.06111549501743381,
#                        'frc6560': -0.02150689528807145,
#                        'frc6705': 0.45571672783114647,
#                        'frc8': 0.36209099727632027,
#                        'frc955': -0.048146013229837872,
#                        'frc973': 0.11119156889215415},
#  'team_score_opr': {'frc1002': 124.21225689931767,
#                     'frc1011': 149.76450747382782,
#                     'frc115': 157.02599133311037,
#                     'frc1339': 125.96798422065335,
#                     'frc1414': 127.96800663206278,
#                     'frc1477': 114.77491503934723,
#                     'frc1482': 69.0555150093343,
#                     'frc1574': 129.3761339809835,
#                     'frc175': 85.116732278878615,
#                     'frc2183': 70.635782080362432,
#                     'frc2403': 134.32245109158634,
#                     'frc2468': 110.41012216879821,
#                     'frc2478': 80.843731553944025,
#                     'frc2485': 88.505690883901536,
#                     'frc2642': 127.18581346587764,
#                     'frc2655': 104.24531198243952,
#                     'frc2881': 76.769491169266217,
#                     'frc2905': 26.417361845177712,
#                     'frc2928': 135.80511381914499,
#                     'frc3140': 90.638557116564897,
#                     'frc3158': 101.14330694999214,
#                     'frc3229': 86.158182066997028,
#                     'frc3316': 122.8078910824091,
#                     'frc3402': 107.46260669487253,
#                     'frc365': 143.49460917929284,
#                     'frc3653': 85.284652499378481,
#                     'frc3824': 126.96309325527585,
#                     'frc3826': 78.089578436795094,
#                     'frc3834': 91.570774782459253,
#                     'frc3991': 67.737826004420498,
#                     'frc4060': 65.914273669761059,
#                     'frc418': 116.62106655170464,
#                     'frc4191': 62.865270011745167,
#                     'frc4219': 89.58675358603395,
#                     'frc4265': 146.76438484413507,
#                     'frc4276': 81.574812779764358,
#                     'frc435': 96.464573727156449,
#                     'frc4371': 67.365329372744029,
#                     'frc441': 91.14940457061212,
#                     'frc4561': 111.0035552863913,
#                     'frc4590': 125.26308475200865,
#                     'frc4592': 98.052651237205382,
#                     'frc4723': 56.810485185257832,
#                     'frc488': 98.055462452243859,
#                     'frc5026': 110.04546378593913,
#                     'frc5472': 54.510742035159851,
#                     'frc5499': 81.076671646280033,
#                     'frc5515': 80.505727211308283,
#                     'frc5614': 107.61788458386496,
#                     'frc5803': 113.73483804756778,
#                     'frc5816': 89.708856584075505,
#                     'frc585': 88.255615668204285,
#                     'frc5970': 122.50535563795165,
#                     'frc6144': 36.696388177764284,
#                     'frc624': 134.76677882359462,
#                     'frc6304': 85.649736210525418,
#                     'frc6325': 119.78641397302121,
#                     'frc6361': 70.175687192783101,
#                     'frc6388': 66.306467100842454,
#                     'frc6409': 8.224131477446484,
#                     'frc6508': 84.873574464767884,
#                     'frc6560': 68.823962846736407,
#                     'frc6705': 111.58307204661151,
#                     'frc8': 114.29890025268708,
#                     'frc955': 75.50753947172737,
#                     'frc973': 177.56919288327293}}

# %%
TeamSummary = namedtuple("TeamSummary", ["last_event", "score_opr", "rotor_rp_opr", "fuel_rp_opr"])

_team_stats = {}

def get_team_last_event(team, year="2017"):
    events = tba.team_events(team, year)
    events = [
        event
        for event
        in events
        if (event['event_type_string'] in ['Regional', 'District Championship', 'District'] and
            event['key'] != '2017micmp') # 2017micmp is messed up in tba so skip it here
    ]
    
    events = sorted(events, key=lambda x: x['end_date'])
    return events[-1]['event_code']

def get_team_stats(team, year="2017"):
    """
    Get the component opr for the given team based on their most recent regional,
    district champ, or district event
    """
    if team not in _team_stats:
        team_last_event = get_team_last_event(team, year)
        eventSummary = get_event_stats(year + team_last_event)
        
        teamSummary = TeamSummary(
            last_event = team_last_event,
            score_opr = eventSummary.team_score_opr[team],
            rotor_rp_opr = eventSummary.team_rotor_rp_opr[team],
            fuel_rp_opr = eventSummary.team_fuel_rp_opr[team],
        )
        
        _team_stats[team] = teamSummary
    
    return _team_stats[team]

get_team_stats('frc973')
# Out:
# TeamSummary(last_event='cada', score_opr=120.68964289866535, rotor_rp_opr=0.0, fuel_rp_opr=0.44310225380396268)

# %%
"""
Simulate one match given the red and blue alliances and creating a MatchOutcome object
"""


import random

MatchOutcome = namedtuple("MatchOutcome", [
        "red_alliance", "blue_alliance",
        "red_score", "blue_score",
        "red_match_rp", "blue_match_rp",
        "red_fuel_rp", "blue_fuel_rp", 
        "red_rotor_rp", "blue_rotor_rp",
        "red_total_rp", "blue_total_rp"
    ])

def simulate_match(red_alliance, blue_alliance):
    red_reports = [get_team_stats(team) for team in red_alliance]
    blue_reports = [get_team_stats(team) for team in blue_alliance]
    
    red_score = sum([
            report.score_opr * random.gauss(1.0, 0.3)
            for report
            in red_reports
    ]) + random.gauss(0.0, 5.0)
    
    blue_score = sum([
            report.score_opr * random.gauss(1.0, 0.3)
            for report
            in blue_reports
    ]) + random.gauss(0.0, 5.0)
    
    if red_score > blue_score:
        red_match_rp = 2
        blue_match_rp = 0
    elif blue_score > red_score:
        blue_match_rp = 2
        red_match_rp = 0
    else:
        blue_match_rp = 1
        red_match_rp = 1
        
    red_rotor_rp_chance = sum([
        report.rotor_rp_opr for report in red_reports
    ])
        
    blue_rotor_rp_chance = sum([
        report.rotor_rp_opr for report in blue_reports
    ])
    
    red_rotor_rp = int(red_rotor_rp_chance > random.random())
    blue_rotor_rp = int(blue_rotor_rp_chance > random.random())
        
    red_fuel_rp_chance = sum([
        report.fuel_rp_opr for report in red_reports
    ])
        
    blue_fuel_rp_chance = sum([
        report.fuel_rp_opr for report in blue_reports
    ])
    
    red_fuel_rp = int(red_fuel_rp_chance > random.random())
    blue_fuel_rp = int(blue_fuel_rp_chance > random.random())
    
    return MatchOutcome(
        red_alliance = red_alliance, blue_alliance = blue_alliance,
        red_score = red_score, blue_score = blue_score,
        red_match_rp = red_match_rp, blue_match_rp = blue_match_rp,
        red_fuel_rp = red_fuel_rp, blue_fuel_rp = blue_fuel_rp,
        red_rotor_rp = red_rotor_rp, blue_rotor_rp = blue_rotor_rp,
        red_total_rp = red_match_rp + red_fuel_rp + red_rotor_rp,
        blue_total_rp = blue_match_rp + blue_fuel_rp + blue_rotor_rp,
    )

for _ in range(3):
    pprint(simulate_match(["frc973", "frc1011", "frc492"], ["frc254", "frc1678", "frc294"])._asdict())
# Out:
# OrderedDict([('red_alliance', ['frc973', 'frc1011', 'frc492']),
#              ('blue_alliance', ['frc254', 'frc1678', 'frc294']),
#              ('red_score', 385.40850430292187),
#              ('blue_score', 573.17096539943748),
#              ('red_match_rp', 0),
#              ('blue_match_rp', 2),
#              ('red_fuel_rp', 1),
#              ('blue_fuel_rp', 1),
#              ('red_rotor_rp', 0),
#              ('blue_rotor_rp', 0),
#              ('red_total_rp', 1),
#              ('blue_total_rp', 3)])
# OrderedDict([('red_alliance', ['frc973', 'frc1011', 'frc492']),
#              ('blue_alliance', ['frc254', 'frc1678', 'frc294']),
#              ('red_score', 267.12670483919203),
#              ('blue_score', 421.12263494093338),
#              ('red_match_rp', 0),
#              ('blue_match_rp', 2),
#              ('red_fuel_rp', 1),
#              ('blue_fuel_rp', 1),
#              ('red_rotor_rp', 0),
#              ('blue_rotor_rp', 1),
#              ('red_total_rp', 1),
#              ('blue_total_rp', 4)])
# OrderedDict([('red_alliance', ['frc973', 'frc1011', 'frc492']),
#              ('blue_alliance', ['frc254', 'frc1678', 'frc294']),
#              ('red_score', 254.16040612933512),
#              ('blue_score', 427.2104178990806),
#              ('red_match_rp', 0),
#              ('blue_match_rp', 2),
#              ('red_fuel_rp', 0),
#              ('blue_fuel_rp', 1),
#              ('red_rotor_rp', 1),
#              ('blue_rotor_rp', 0),
#              ('red_total_rp', 1),
#              ('blue_total_rp', 3)])

# %%
def get_schedule(event):
    """
    Given an event key return the schedule (a list of (red_alliance, blue_alliance) tuples)
    """
    schedule = []
    event_matches = tba.event_matches(event)
    for match in event_matches:
        schedule.append((match['alliances']['red']['team_keys'],
                         match['alliances']['blue']['team_keys']))
    
    return schedule

def simulate_schedule(schedule):
    """
    Given a schedule, simulate the outcomes of all matches
    """
    outcomes = []
    for match in schedule:
        outcomes.append(simulate_match(match[0], match[1]))
    return outcomes

def get_rankings(match_outcomes):
    "Based on the outcomes of each match, determine the rankings"
    teams = set().union(*[match.red_alliance for match in match_outcomes])
    
    team_rps = []
    for team in teams:
        num_rps = 0
        for outcome in match_outcomes:
            if team in outcome.red_alliance:
                num_rps += outcome.red_total_rp
            if team in outcome.blue_alliance:
                num_rps += outcome.blue_total_rp
        team_rps.append((team, num_rps))
    team_rps.sort(key=lambda x: -x[1])
    
    rankings = {}
    for idx, (team, rps) in enumerate(team_rps):
        rankings[team] = idx + 1
        
    return rankings
        
def simulate_event(event):
    return get_rankings(simulate_schedule(get_schedule(event)))

pprint(simulate_event("2017roe"))
# Out:
# {'frc1002': 3,
#  'frc1011': 7,
#  'frc115': 17,
#  'frc1339': 54,
#  'frc1414': 18,
#  'frc1477': 36,
#  'frc1482': 37,
#  'frc1574': 5,
#  'frc175': 48,
#  'frc2183': 52,
#  'frc2403': 35,
#  'frc2468': 11,
#  'frc2478': 12,
#  'frc2485': 63,
#  'frc2642': 15,
#  'frc2655': 29,
#  'frc2881': 61,
#  'frc2905': 20,
#  'frc2928': 4,
#  'frc3140': 55,
#  'frc3158': 50,
#  'frc3229': 43,
#  'frc3316': 41,
#  'frc3402': 33,
#  'frc365': 1,
#  'frc3653': 23,
#  'frc3824': 10,
#  'frc3826': 40,
#  'frc3834': 65,
#  'frc3991': 24,
#  'frc4060': 60,
#  'frc418': 9,
#  'frc4191': 66,
#  'frc4219': 59,
#  'frc4265': 13,
#  'frc4276': 30,
#  'frc435': 28,
#  'frc4371': 46,
#  'frc441': 42,
#  'frc4561': 21,
#  'frc4590': 38,
#  'frc4592': 16,
#  'frc4723': 56,
#  'frc488': 14,
#  'frc5026': 27,
#  'frc5472': 51,
#  'frc5499': 25,
#  'frc5515': 47,
#  'frc5614': 34,
#  'frc5803': 19,
#  'frc5816': 39,
#  'frc585': 32,
#  'frc5970': 26,
#  'frc6144': 49,
#  'frc624': 8,
#  'frc6304': 62,
#  'frc6325': 57,
#  'frc6361': 58,
#  'frc6388': 64,
#  'frc6409': 53,
#  'frc6508': 22,
#  'frc6560': 45,
#  'frc6705': 31,
#  'frc8': 2,
#  'frc955': 44,
#  'frc973': 6}

# %%
AggregateRanking = namedtuple("AggregateRanking", ["p0", "p100", "p50", "p75", "p25", "std_dev"])

def monte_carlo_event(event, iterations=1000):
    team_ranks = {}
    
    for _ in range(iterations):
        rankings = simulate_event(event)
        for team, rank in rankings.items():
            if team not in team_ranks:
                team_ranks[team] = []
            team_ranks[team].append(rank)
    
    aggregate_rankings = {}
    for team, rankings in team_ranks.items():
        aggregate_rankings[team] = AggregateRanking(
            p0=np.percentile(rankings, 0),
            p100=np.percentile(rankings, 100),
            p50=np.percentile(rankings, 50),
            p75=np.percentile(rankings, 75),
            p25=np.percentile(rankings, 25),
            std_dev=np.std(rankings),
        )
    
    return aggregate_rankings

def get_actual_ranking(event, team):
    event_rankings = tba.event_rankings(event)
    for ranking in event_rankings['rankings']:
        if ranking['team_key'] == team:
            return ranking['rank']
    raise Exception("Team Not Found: " + team)

def display_monte_carlo_result(monte_carlo_result, event):
    monte_carlo_result = list(monte_carlo_result.items())
    monte_carlo_result.sort(key=lambda x: (x[1].p50, x[1].p75))
    
    for team, agr_rank in monte_carlo_result:
        print("Predicted Rank {0:2.0f}: {1:10s} (25p={2:2.0f}, 75p={3:2.0f})   Actual Rank: {4}".format(
                agr_rank.p50, team, agr_rank.p25, agr_rank.p75, get_actual_ranking(event, team)))

display_monte_carlo_result(monte_carlo_event("2017roe", iterations=10), "2017roe")
# Out:
# Predicted Rank  2: frc1574    (25p= 2, 75p= 3)   Actual Rank: 4
# Predicted Rank  2: frc973     (25p= 1, 75p= 4)   Actual Rank: 1
# Predicted Rank  2: frc365     (25p= 2, 75p= 4)   Actual Rank: 7
# Predicted Rank  6: frc2928    (25p= 4, 75p= 7)   Actual Rank: 38
# Predicted Rank  6: frc1011    (25p= 4, 75p= 8)   Actual Rank: 8
# Predicted Rank  8: frc6705    (25p= 7, 75p=18)   Actual Rank: 3
# Predicted Rank  9: frc115     (25p= 7, 75p=12)   Actual Rank: 2
# Predicted Rank 10: frc418     (25p= 5, 75p=15)   Actual Rank: 42
# Predicted Rank 10: frc2468    (25p= 5, 75p=15)   Actual Rank: 37
# Predicted Rank 10: frc4561    (25p= 8, 75p=17)   Actual Rank: 29
# Predicted Rank 12: frc8       (25p=10, 75p=15)   Actual Rank: 36
# Predicted Rank 13: frc1002    (25p=12, 75p=17)   Actual Rank: 14
# Predicted Rank 13: frc624     (25p= 9, 75p=17)   Actual Rank: 28
# Predicted Rank 14: frc4265    (25p= 8, 75p=17)   Actual Rank: 5
# Predicted Rank 16: frc4592    (25p=13, 75p=19)   Actual Rank: 6
# Predicted Rank 16: frc3824    (25p=12, 75p=20)   Actual Rank: 27
# Predicted Rank 18: frc1414    (25p=16, 75p=28)   Actual Rank: 17
# Predicted Rank 18: frc1477    (25p=17, 75p=26)   Actual Rank: 10
# Predicted Rank 19: frc5499    (25p=14, 75p=30)   Actual Rank: 32
# Predicted Rank 20: frc2478    (25p=13, 75p=30)   Actual Rank: 15
# Predicted Rank 20: frc3229    (25p=19, 75p=24)   Actual Rank: 12
# Predicted Rank 22: frc488     (25p=17, 75p=32)   Actual Rank: 13
# Predicted Rank 24: frc955     (25p=22, 75p=27)   Actual Rank: 31
# Predicted Rank 24: frc3653    (25p=15, 75p=31)   Actual Rank: 33
# Predicted Rank 24: frc5803    (25p=19, 75p=36)   Actual Rank: 57
# Predicted Rank 26: frc2642    (25p=20, 75p=35)   Actual Rank: 9
# Predicted Rank 30: frc2403    (25p=28, 75p=32)   Actual Rank: 22
# Predicted Rank 32: frc3826    (25p=26, 75p=38)   Actual Rank: 46
# Predicted Rank 32: frc3402    (25p=27, 75p=35)   Actual Rank: 56
# Predicted Rank 32: frc5026    (25p=25, 75p=37)   Actual Rank: 43
# Predicted Rank 32: frc3991    (25p=28, 75p=40)   Actual Rank: 26
# Predicted Rank 33: frc6508    (25p=27, 75p=41)   Actual Rank: 24
# Predicted Rank 33: frc5515    (25p=25, 75p=41)   Actual Rank: 20
# Predicted Rank 34: frc5472    (25p=29, 75p=40)   Actual Rank: 52
# Predicted Rank 34: frc2655    (25p=31, 75p=44)   Actual Rank: 19
# Predicted Rank 35: frc5970    (25p=33, 75p=38)   Actual Rank: 18
# Predicted Rank 36: frc4590    (25p=33, 75p=38)   Actual Rank: 23
# Predicted Rank 36: frc435     (25p=26, 75p=37)   Actual Rank: 41
# Predicted Rank 37: frc1339    (25p=32, 75p=48)   Actual Rank: 11
# Predicted Rank 39: frc441     (25p=34, 75p=44)   Actual Rank: 59
# Predicted Rank 40: frc5614    (25p=32, 75p=43)   Actual Rank: 48
# Predicted Rank 42: frc2905    (25p=28, 75p=44)   Actual Rank: 66
# Predicted Rank 42: frc3140    (25p=38, 75p=49)   Actual Rank: 50
# Predicted Rank 46: frc4276    (25p=32, 75p=50)   Actual Rank: 16
# Predicted Rank 46: frc5816    (25p=44, 75p=48)   Actual Rank: 35
# Predicted Rank 48: frc2881    (25p=44, 75p=55)   Actual Rank: 44
# Predicted Rank 48: frc4371    (25p=42, 75p=56)   Actual Rank: 53
# Predicted Rank 48: frc3158    (25p=43, 75p=56)   Actual Rank: 49
# Predicted Rank 50: frc3316    (25p=43, 75p=54)   Actual Rank: 40
# Predicted Rank 50: frc1482    (25p=47, 75p=56)   Actual Rank: 25
# Predicted Rank 50: frc6560    (25p=39, 75p=56)   Actual Rank: 45
# Predicted Rank 51: frc2485    (25p=44, 75p=54)   Actual Rank: 47
# Predicted Rank 52: frc2183    (25p=48, 75p=58)   Actual Rank: 65
# Predicted Rank 54: frc4723    (25p=52, 75p=57)   Actual Rank: 39
# Predicted Rank 54: frc175     (25p=48, 75p=58)   Actual Rank: 21
# Predicted Rank 55: frc6409    (25p=54, 75p=60)   Actual Rank: 61
# Predicted Rank 57: frc6361    (25p=50, 75p=59)   Actual Rank: 51
# Predicted Rank 57: frc6144    (25p=52, 75p=60)   Actual Rank: 54
# Predicted Rank 57: frc6388    (25p=49, 75p=60)   Actual Rank: 58
# Predicted Rank 57: frc6304    (25p=54, 75p=62)   Actual Rank: 60
# Predicted Rank 58: frc6325    (25p=52, 75p=64)   Actual Rank: 34
# Predicted Rank 60: frc585     (25p=55, 75p=61)   Actual Rank: 55
# Predicted Rank 60: frc4219    (25p=54, 75p=62)   Actual Rank: 30
# Predicted Rank 62: frc4060    (25p=55, 75p=63)   Actual Rank: 63
# Predicted Rank 64: frc3834    (25p=63, 75p=66)   Actual Rank: 62
# Predicted Rank 65: frc4191    (25p=64, 75p=66)   Actual Rank: 64

# %%
import math 

def norm_pdf(x, mean, sd):
    """
    Probability distribution function for a normal curve
    """
    var = float(sd) ** 2
    denom = (2 * math.pi * var) ** 0.5
    num = math.exp(-(float(x) - float(mean)) ** 2 / (2 * var))
    return num / denom

def score_monte_carlo_prediction(monte_carlo_result, event):
    """
    Assuming the model we generated using monte carlo metrics, calculate how
    likely the actual rankings were (do sum of log of probabilities because
    of floating point error... closer to zero is higher probability and more
    negative is lesser probability)
    
    Only look at the first 16 or so teams because everything after that will
    be a shitshow regardless.
    """
    monte_carlo_result = list(monte_carlo_result.items())
    monte_carlo_result = sorted(monte_carlo_result, key=lambda x: (x[1].p50, x[1].p75))[:16]
    
    team_probabilities = {}
    for team, prediction in monte_carlo_result:
        mean = prediction.p50
        sd = prediction.std_dev
        #team_probabilities[team] = math.log(norm_pdf(get_actual_ranking(event, team), mean, sd))
        team_probabilities[team] = abs(mean - get_actual_ranking(event, team))
        
    return sum(team_probabilities.values()) / len(team_probabilities)

pprint(score_monte_carlo_prediction(monte_carlo_event("2017roe", iterations=10), "2017roe"))
# Out:
# 11.75

# %%
display_monte_carlo_result(monte_carlo_event("2017new", iterations=10), "2017new")
# Out:
# Predicted Rank  1: frc118     (25p= 1, 75p= 1)   Actual Rank: 1
# Predicted Rank  2: frc1678    (25p= 2, 75p= 3)   Actual Rank: 3
# Predicted Rank  3: frc330     (25p= 2, 75p= 4)   Actual Rank: 2
# Predicted Rank  4: frc4188    (25p= 3, 75p= 5)   Actual Rank: 18
# Predicted Rank  4: frc180     (25p= 4, 75p= 5)   Actual Rank: 7
# Predicted Rank  6: frc3663    (25p= 5, 75p= 6)   Actual Rank: 29
# Predicted Rank  8: frc696     (25p= 7, 75p=13)   Actual Rank: 59
# Predicted Rank 10: frc4486    (25p= 9, 75p=12)   Actual Rank: 5
# Predicted Rank 10: frc3255    (25p= 8, 75p=14)   Actual Rank: 12
# Predicted Rank 10: frc3647    (25p= 8, 75p=12)   Actual Rank: 8
# Predicted Rank 12: frc3008    (25p= 8, 75p=13)   Actual Rank: 4
# Predicted Rank 13: frc3473    (25p=11, 75p=14)   Actual Rank: 9
# Predicted Rank 14: frc2073    (25p=10, 75p=16)   Actual Rank: 6
# Predicted Rank 15: frc3489    (25p= 9, 75p=26)   Actual Rank: 31
# Predicted Rank 16: frc997     (25p=11, 75p=22)   Actual Rank: 17
# Predicted Rank 17: frc704     (25p=12, 75p=20)   Actual Rank: 14
# Predicted Rank 18: frc4469    (25p=14, 75p=25)   Actual Rank: 21
# Predicted Rank 20: frc3616    (25p=17, 75p=21)   Actual Rank: 34
# Predicted Rank 21: frc4662    (25p=18, 75p=27)   Actual Rank: 28
# Predicted Rank 22: frc5635    (25p=19, 75p=28)   Actual Rank: 15
# Predicted Rank 25: frc1533    (25p=22, 75p=26)   Actual Rank: 32
# Predicted Rank 25: frc900     (25p=17, 75p=27)   Actual Rank: 45
# Predicted Rank 25: frc5842    (25p=22, 75p=35)   Actual Rank: 13
# Predicted Rank 26: frc3735    (25p=19, 75p=28)   Actual Rank: 43
# Predicted Rank 26: frc5295    (25p=20, 75p=31)   Actual Rank: 16
# Predicted Rank 28: frc4320    (25p=23, 75p=32)   Actual Rank: 38
# Predicted Rank 28: frc1156    (25p=24, 75p=32)   Actual Rank: 35
# Predicted Rank 28: frc5839    (25p=20, 75p=37)   Actual Rank: 30
# Predicted Rank 31: frc2096    (25p=21, 75p=32)   Actual Rank: 19
# Predicted Rank 32: frc1294    (25p=26, 75p=40)   Actual Rank: 26
# Predicted Rank 32: frc3335    (25p=30, 75p=37)   Actual Rank: 41
# Predicted Rank 33: frc79      (25p=28, 75p=40)   Actual Rank: 25
# Predicted Rank 34: frc2839    (25p=24, 75p=36)   Actual Rank: 40
# Predicted Rank 34: frc6369    (25p=30, 75p=45)   Actual Rank: 27
# Predicted Rank 36: frc1255    (25p=25, 75p=40)   Actual Rank: 37
# Predicted Rank 36: frc60      (25p=28, 75p=44)   Actual Rank: 33
# Predicted Rank 37: frc4189    (25p=30, 75p=41)   Actual Rank: 11
# Predicted Rank 37: frc6418    (25p=32, 75p=44)   Actual Rank: 24
# Predicted Rank 38: frc159     (25p=29, 75p=52)   Actual Rank: 22
# Predicted Rank 38: frc1745    (25p=34, 75p=43)   Actual Rank: 42
# Predicted Rank 38: frc5892    (25p=34, 75p=45)   Actual Rank: 47
# Predicted Rank 39: frc5869    (25p=37, 75p=47)   Actual Rank: 54
# Predicted Rank 44: frc6546    (25p=39, 75p=58)   Actual Rank: 23
# Predicted Rank 46: frc120     (25p=42, 75p=49)   Actual Rank: 49
# Predicted Rank 46: frc4918    (25p=36, 75p=51)   Actual Rank: 39
# Predicted Rank 46: frc744     (25p=42, 75p=50)   Actual Rank: 10
# Predicted Rank 46: frc6652    (25p=42, 75p=57)   Actual Rank: 44
# Predicted Rank 47: frc1622    (25p=36, 75p=56)   Actual Rank: 36
# Predicted Rank 48: frc6666    (25p=45, 75p=56)   Actual Rank: 62
# Predicted Rank 50: frc5930    (25p=44, 75p=56)   Actual Rank: 57
# Predicted Rank 50: frc6321    (25p=45, 75p=56)   Actual Rank: 56
# Predicted Rank 51: frc6377    (25p=43, 75p=58)   Actual Rank: 63
# Predicted Rank 52: frc5012    (25p=44, 75p=53)   Actual Rank: 20
# Predicted Rank 53: frc3743    (25p=48, 75p=58)   Actual Rank: 50
# Predicted Rank 54: frc6025    (25p=46, 75p=59)   Actual Rank: 48
# Predicted Rank 54: frc3189    (25p=53, 75p=55)   Actual Rank: 67
# Predicted Rank 54: frc1369    (25p=44, 75p=60)   Actual Rank: 53
# Predicted Rank 56: frc4013    (25p=46, 75p=63)   Actual Rank: 60
# Predicted Rank 58: frc5160    (25p=52, 75p=64)   Actual Rank: 66
# Predicted Rank 58: frc3847    (25p=53, 75p=60)   Actual Rank: 51
# Predicted Rank 60: frc968     (25p=53, 75p=61)   Actual Rank: 55
# Predicted Rank 60: frc3556    (25p=55, 75p=63)   Actual Rank: 52
# Predicted Rank 62: frc589     (25p=62, 75p=65)   Actual Rank: 61
# Predicted Rank 63: frc3218    (25p=54, 75p=63)   Actual Rank: 58
# Predicted Rank 63: frc6430    (25p=60, 75p=66)   Actual Rank: 64
# Predicted Rank 63: frc2240    (25p=60, 75p=66)   Actual Rank: 46
# Predicted Rank 64: frc3527    (25p=59, 75p=66)   Actual Rank: 65

# %%
display_monte_carlo_result(monte_carlo_event("2017cur", iterations=10), "2017cur")
# Out:
# Predicted Rank  1: frc2056    (25p= 1, 75p= 1)   Actual Rank: 1
# Predicted Rank  2: frc384     (25p= 2, 75p= 2)   Actual Rank: 59
# Predicted Rank  3: frc1241    (25p= 3, 75p= 4)   Actual Rank: 12
# Predicted Rank  5: frc2481    (25p= 4, 75p= 7)   Actual Rank: 2
# Predicted Rank  6: frc203     (25p= 4, 75p= 8)   Actual Rank: 40
# Predicted Rank  7: frc4917    (25p= 5, 75p=12)   Actual Rank: 6
# Predicted Rank  9: frc2791    (25p= 6, 75p=12)   Actual Rank: 45
# Predicted Rank 10: frc230     (25p= 8, 75p=11)   Actual Rank: 11
# Predicted Rank 10: frc4946    (25p= 6, 75p=12)   Actual Rank: 9
# Predicted Rank 10: frc2169    (25p= 8, 75p=12)   Actual Rank: 14
# Predicted Rank 10: frc6009    (25p= 6, 75p=12)   Actual Rank: 3
# Predicted Rank 12: frc71      (25p=10, 75p=15)   Actual Rank: 8
# Predicted Rank 14: frc4143    (25p=12, 75p=17)   Actual Rank: 16
# Predicted Rank 14: frc4500    (25p=12, 75p=24)   Actual Rank: 4
# Predicted Rank 18: frc2609    (25p=16, 75p=24)   Actual Rank: 58
# Predicted Rank 18: frc4039    (25p=12, 75p=24)   Actual Rank: 46
# Predicted Rank 18: frc234     (25p=14, 75p=23)   Actual Rank: 44
# Predicted Rank 20: frc226     (25p=17, 75p=30)   Actual Rank: 15
# Predicted Rank 20: frc5205    (25p=10, 75p=21)   Actual Rank: 17
# Predicted Rank 21: frc4272    (25p=18, 75p=25)   Actual Rank: 21
# Predicted Rank 21: frc2410    (25p=20, 75p=26)   Actual Rank: 28
# Predicted Rank 21: frc1807    (25p=17, 75p=26)   Actual Rank: 29
# Predicted Rank 24: frc1720    (25p=15, 75p=25)   Actual Rank: 26
# Predicted Rank 24: frc3098    (25p=20, 75p=30)   Actual Rank: 54
# Predicted Rank 25: frc494     (25p=18, 75p=31)   Actual Rank: 7
# Predicted Rank 26: frc1918    (25p=25, 75p=31)   Actual Rank: 34
# Predicted Rank 28: frc5155    (25p=20, 75p=29)   Actual Rank: 5
# Predicted Rank 30: frc2252    (25p=22, 75p=36)   Actual Rank: 18
# Predicted Rank 31: frc470     (25p=24, 75p=41)   Actual Rank: 42
# Predicted Rank 32: frc1598    (25p=28, 75p=36)   Actual Rank: 47
# Predicted Rank 33: frc3929    (25p=27, 75p=38)   Actual Rank: 43
# Predicted Rank 34: frc1675    (25p=26, 75p=37)   Actual Rank: 23
# Predicted Rank 34: frc2500    (25p=30, 75p=37)   Actual Rank: 52
# Predicted Rank 35: frc4750    (25p=30, 75p=44)   Actual Rank: 31
# Predicted Rank 36: frc5885    (25p=32, 75p=41)   Actual Rank: 10
# Predicted Rank 36: frc5801    (25p=32, 75p=40)   Actual Rank: 13
# Predicted Rank 37: frc6424    (25p=32, 75p=41)   Actual Rank: 20
# Predicted Rank 38: frc1714    (25p=34, 75p=44)   Actual Rank: 55
# Predicted Rank 40: frc2077    (25p=34, 75p=45)   Actual Rank: 61
# Predicted Rank 40: frc1511    (25p=38, 75p=51)   Actual Rank: 51
# Predicted Rank 40: frc935     (25p=30, 75p=54)   Actual Rank: 50
# Predicted Rank 41: frc3293    (25p=36, 75p=49)   Actual Rank: 27
# Predicted Rank 42: frc3142    (25p=29, 75p=44)   Actual Rank: 53
# Predicted Rank 43: frc4207    (25p=41, 75p=55)   Actual Rank: 63
# Predicted Rank 44: frc6075    (25p=30, 75p=60)   Actual Rank: 35
# Predicted Rank 47: frc6381    (25p=37, 75p=49)   Actual Rank: 24
# Predicted Rank 48: frc449     (25p=46, 75p=56)   Actual Rank: 37
# Predicted Rank 49: frc3260    (25p=43, 75p=52)   Actual Rank: 36
# Predicted Rank 50: frc5980    (25p=45, 75p=56)   Actual Rank: 56
# Predicted Rank 51: frc6613    (25p=47, 75p=58)   Actual Rank: 19
# Predicted Rank 52: frc3875    (25p=48, 75p=58)   Actual Rank: 49
# Predicted Rank 52: frc747     (25p=46, 75p=59)   Actual Rank: 57
# Predicted Rank 54: frc5086    (25p=48, 75p=60)   Actual Rank: 30
# Predicted Rank 54: frc2534    (25p=52, 75p=60)   Actual Rank: 32
# Predicted Rank 54: frc101     (25p=46, 75p=61)   Actual Rank: 65
# Predicted Rank 54: frc3386    (25p=47, 75p=60)   Actual Rank: 41
# Predicted Rank 54: frc2457    (25p=47, 75p=60)   Actual Rank: 39
# Predicted Rank 56: frc5553    (25p=48, 75p=64)   Actual Rank: 25
# Predicted Rank 56: frc1625    (25p=48, 75p=63)   Actual Rank: 62
# Predicted Rank 57: frc354     (25p=53, 75p=59)   Actual Rank: 68
# Predicted Rank 57: frc5222    (25p=54, 75p=62)   Actual Rank: 33
# Predicted Rank 58: frc6630    (25p=54, 75p=64)   Actual Rank: 22
# Predicted Rank 59: frc329     (25p=56, 75p=64)   Actual Rank: 38
# Predicted Rank 60: frc1086    (25p=53, 75p=63)   Actual Rank: 67
# Predicted Rank 62: frc6753    (25p=51, 75p=66)   Actual Rank: 60
# Predicted Rank 63: frc6758    (25p=54, 75p=64)   Actual Rank: 64
# Predicted Rank 64: frc4522    (25p=60, 75p=67)   Actual Rank: 66
# Predicted Rank 65: frc2781    (25p=62, 75p=66)   Actual Rank: 48

# %%
display_monte_carlo_result(monte_carlo_event("2017gal", iterations=10), "2017gal")
# Out:
# Predicted Rank  2: frc1538    (25p= 1, 75p= 4)   Actual Rank: 2
# Predicted Rank  3: frc492     (25p= 1, 75p= 5)   Actual Rank: 1
# Predicted Rank  3: frc2630    (25p= 2, 75p= 7)   Actual Rank: 46
# Predicted Rank  4: frc5654    (25p= 2, 75p= 6)   Actual Rank: 7
# Predicted Rank  6: frc3211    (25p= 5, 75p= 8)   Actual Rank: 33
# Predicted Rank  6: frc3478    (25p= 4, 75p=10)   Actual Rank: 14
# Predicted Rank  6: frc2576    (25p= 5, 75p=10)   Actual Rank: 53
# Predicted Rank  8: frc498     (25p= 4, 75p= 9)   Actual Rank: 3
# Predicted Rank 10: frc2415    (25p= 8, 75p=12)   Actual Rank: 18
# Predicted Rank 10: frc5074    (25p= 4, 75p=13)   Actual Rank: 17
# Predicted Rank 10: frc3635    (25p= 9, 75p=14)   Actual Rank: 32
# Predicted Rank 12: frc2231    (25p=10, 75p=16)   Actual Rank: 6
# Predicted Rank 13: frc368     (25p=11, 75p=19)   Actual Rank: 31
# Predicted Rank 14: frc3005    (25p=12, 75p=27)   Actual Rank: 11
# Predicted Rank 16: frc192     (25p=12, 75p=19)   Actual Rank: 15
# Predicted Rank 17: frc587     (25p=16, 75p=21)   Actual Rank: 23
# Predicted Rank 19: frc2333    (25p=16, 75p=26)   Actual Rank: 9
# Predicted Rank 20: frc701     (25p=16, 75p=24)   Actual Rank: 13
# Predicted Rank 21: frc6579    (25p=18, 75p=30)   Actual Rank: 26
# Predicted Rank 22: frc6445    (25p=18, 75p=32)   Actual Rank: 4
# Predicted Rank 22: frc2486    (25p=20, 75p=26)   Actual Rank: 16
# Predicted Rank 25: frc386     (25p=19, 75p=27)   Actual Rank: 10
# Predicted Rank 25: frc4499    (25p=18, 75p=30)   Actual Rank: 12
# Predicted Rank 25: frc4516    (25p=18, 75p=32)   Actual Rank: 5
# Predicted Rank 26: frc86      (25p=19, 75p=28)   Actual Rank: 28
# Predicted Rank 27: frc4388    (25p=24, 75p=36)   Actual Rank: 25
# Predicted Rank 28: frc4355    (25p=21, 75p=32)   Actual Rank: 20
# Predicted Rank 29: frc4112    (25p=26, 75p=35)   Actual Rank: 22
# Predicted Rank 29: frc6547    (25p=26, 75p=36)   Actual Rank: 27
# Predicted Rank 32: frc4537    (25p=21, 75p=35)   Actual Rank: 8
# Predicted Rank 35: frc4904    (25p=31, 75p=38)   Actual Rank: 36
# Predicted Rank 36: frc4080    (25p=30, 75p=38)   Actual Rank: 21
# Predicted Rank 37: frc6061    (25p=34, 75p=40)   Actual Rank: 43
# Predicted Rank 37: frc2152    (25p=28, 75p=44)   Actual Rank: 30
# Predicted Rank 38: frc5109    (25p=32, 75p=41)   Actual Rank: 39
# Predicted Rank 39: frc3507    (25p=33, 75p=48)   Actual Rank: 42
# Predicted Rank 40: frc5437    (25p=34, 75p=47)   Actual Rank: 19
# Predicted Rank 42: frc3966    (25p=37, 75p=55)   Actual Rank: 50
# Predicted Rank 42: frc4201    (25p=27, 75p=44)   Actual Rank: 65
# Predicted Rank 42: frc3959    (25p=26, 75p=48)   Actual Rank: 47
# Predicted Rank 43: frc3045    (25p=31, 75p=53)   Actual Rank: 24
# Predicted Rank 44: frc662     (25p=41, 75p=45)   Actual Rank: 48
# Predicted Rank 44: frc2135    (25p=34, 75p=53)   Actual Rank: 54
# Predicted Rank 44: frc5190    (25p=33, 75p=48)   Actual Rank: 55
# Predicted Rank 46: frc3303    (25p=42, 75p=49)   Actual Rank: 38
# Predicted Rank 46: frc4534    (25p=38, 75p=51)   Actual Rank: 63
# Predicted Rank 46: frc4335    (25p=33, 75p=54)   Actual Rank: 29
# Predicted Rank 46: frc6357    (25p=33, 75p=54)   Actual Rank: 34
# Predicted Rank 47: frc1817    (25p=35, 75p=49)   Actual Rank: 64
# Predicted Rank 47: frc5572    (25p=42, 75p=52)   Actual Rank: 58
# Predicted Rank 48: frc5414    (25p=43, 75p=50)   Actual Rank: 44
# Predicted Rank 50: frc4010    (25p=47, 75p=55)   Actual Rank: 37
# Predicted Rank 51: frc3574    (25p=44, 75p=58)   Actual Rank: 35
# Predicted Rank 52: frc4364    (25p=50, 75p=56)   Actual Rank: 41
# Predicted Rank 52: frc6171    (25p=42, 75p=59)   Actual Rank: 62
# Predicted Rank 54: frc3512    (25p=49, 75p=56)   Actual Rank: 59
# Predicted Rank 54: frc4841    (25p=42, 75p=61)   Actual Rank: 56
# Predicted Rank 56: frc6404    (25p=48, 75p=58)   Actual Rank: 45
# Predicted Rank 56: frc199     (25p=51, 75p=61)   Actual Rank: 40
# Predicted Rank 58: frc6411    (25p=52, 75p=62)   Actual Rank: 52
# Predicted Rank 60: frc5696    (25p=55, 75p=65)   Actual Rank: 61
# Predicted Rank 62: frc6474    (25p=53, 75p=63)   Actual Rank: 66
# Predicted Rank 62: frc5411    (25p=58, 75p=64)   Actual Rank: 57
# Predicted Rank 62: frc6739    (25p=60, 75p=64)   Actual Rank: 49
# Predicted Rank 62: frc6191    (25p=58, 75p=65)   Actual Rank: 51
# Predicted Rank 64: frc6464    (25p=61, 75p=66)   Actual Rank: 60
# Predicted Rank 64: frc6658    (25p=62, 75p=66)   Actual Rank: 67

# %%
display_monte_carlo_result(monte_carlo_event("2017cars", iterations=10), "2017cars")
# Out:
# Predicted Rank  1: frc195     (25p= 1, 75p= 2)   Actual Rank: 5
# Predicted Rank  2: frc125     (25p= 1, 75p= 4)   Actual Rank: 3
# Predicted Rank  4: frc1080    (25p= 3, 75p= 4)   Actual Rank: 26
# Predicted Rank  4: frc5687    (25p= 3, 75p= 5)   Actual Rank: 6
# Predicted Rank  4: frc1796    (25p= 3, 75p= 5)   Actual Rank: 15
# Predicted Rank  6: frc33      (25p= 6, 75p= 7)   Actual Rank: 2
# Predicted Rank  9: frc5024    (25p= 7, 75p=13)   Actual Rank: 7
# Predicted Rank  9: frc135     (25p= 8, 75p=17)   Actual Rank: 4
# Predicted Rank 10: frc177     (25p= 7, 75p=12)   Actual Rank: 27
# Predicted Rank 12: frc1073    (25p= 8, 75p=13)   Actual Rank: 24
# Predicted Rank 14: frc2451    (25p=10, 75p=16)   Actual Rank: 21
# Predicted Rank 14: frc1018    (25p=10, 75p=16)   Actual Rank: 13
# Predicted Rank 14: frc303     (25p=10, 75p=22)   Actual Rank: 1
# Predicted Rank 14: frc6329    (25p=13, 75p=18)   Actual Rank: 37
# Predicted Rank 15: frc2052    (25p=11, 75p=16)   Actual Rank: 33
# Predicted Rank 18: frc4253    (25p=13, 75p=26)   Actual Rank: 16
# Predicted Rank 20: frc876     (25p=16, 75p=26)   Actual Rank: 30
# Predicted Rank 20: frc5401    (25p=17, 75p=28)   Actual Rank: 23
# Predicted Rank 22: frc2194    (25p=18, 75p=26)   Actual Rank: 43
# Predicted Rank 24: frc4003    (25p=22, 75p=25)   Actual Rank: 10
# Predicted Rank 24: frc3381    (25p=18, 75p=30)   Actual Rank: 52
# Predicted Rank 26: frc68      (25p=21, 75p=38)   Actual Rank: 50
# Predicted Rank 26: frc4237    (25p=23, 75p=35)   Actual Rank: 8
# Predicted Rank 28: frc1732    (25p=20, 75p=33)   Actual Rank: 22
# Predicted Rank 28: frc5813    (25p=20, 75p=35)   Actual Rank: 12
# Predicted Rank 28: frc20      (25p=21, 75p=36)   Actual Rank: 44
# Predicted Rank 29: frc2832    (25p=24, 75p=32)   Actual Rank: 31
# Predicted Rank 29: frc1684    (25p=21, 75p=34)   Actual Rank: 38
# Predicted Rank 30: frc3941    (25p=21, 75p=36)   Actual Rank: 39
# Predicted Rank 30: frc1710    (25p=24, 75p=42)   Actual Rank: 20
# Predicted Rank 32: frc3538    (25p=20, 75p=43)   Actual Rank: 57
# Predicted Rank 32: frc4176    (25p=29, 75p=46)   Actual Rank: 41
# Predicted Rank 33: frc4456    (25p=29, 75p=37)   Actual Rank: 45
# Predicted Rank 34: frc1153    (25p=23, 75p=46)   Actual Rank: 17
# Predicted Rank 37: frc6336    (25p=26, 75p=51)   Actual Rank: 60
# Predicted Rank 38: frc4905    (25p=34, 75p=42)   Actual Rank: 63
# Predicted Rank 38: frc1288    (25p=30, 75p=41)   Actual Rank: 64
# Predicted Rank 39: frc5462    (25p=29, 75p=47)   Actual Rank: 65
# Predicted Rank 41: frc4198    (25p=36, 75p=48)   Actual Rank: 36
# Predicted Rank 41: frc126     (25p=33, 75p=53)   Actual Rank: 35
# Predicted Rank 42: frc5150    (25p=30, 75p=48)   Actual Rank: 42
# Predicted Rank 42: frc6569    (25p=38, 75p=52)   Actual Rank: 49
# Predicted Rank 42: frc2399    (25p=33, 75p=55)   Actual Rank: 32
# Predicted Rank 44: frc503     (25p=32, 75p=56)   Actual Rank: 48
# Predicted Rank 44: frc25      (25p=36, 75p=60)   Actual Rank: 25
# Predicted Rank 45: frc1731    (25p=40, 75p=54)   Actual Rank: 51
# Predicted Rank 45: frc4961    (25p=38, 75p=56)   Actual Rank: 18
# Predicted Rank 46: frc5114    (25p=42, 75p=54)   Actual Rank: 9
# Predicted Rank 48: frc5618    (25p=39, 75p=53)   Actual Rank: 47
# Predicted Rank 48: frc2491    (25p=39, 75p=56)   Actual Rank: 53
# Predicted Rank 49: frc6420    (25p=41, 75p=57)   Actual Rank: 62
# Predicted Rank 51: frc263     (25p=46, 75p=53)   Actual Rank: 61
# Predicted Rank 51: frc639     (25p=46, 75p=60)   Actual Rank: 29
# Predicted Rank 52: frc5053    (25p=45, 75p=60)   Actual Rank: 19
# Predicted Rank 52: frc597     (25p=42, 75p=60)   Actual Rank: 56
# Predicted Rank 52: frc4539    (25p=50, 75p=58)   Actual Rank: 67
# Predicted Rank 53: frc1991    (25p=40, 75p=63)   Actual Rank: 46
# Predicted Rank 54: frc341     (25p=44, 75p=58)   Actual Rank: 54
# Predicted Rank 54: frc2601    (25p=45, 75p=59)   Actual Rank: 59
# Predicted Rank 54: frc4959    (25p=52, 75p=63)   Actual Rank: 40
# Predicted Rank 57: frc1816    (25p=55, 75p=57)   Actual Rank: 28
# Predicted Rank 58: frc6324    (25p=41, 75p=63)   Actual Rank: 14
# Predicted Rank 59: frc6066    (25p=54, 75p=63)   Actual Rank: 55
# Predicted Rank 60: frc2377    (25p=53, 75p=63)   Actual Rank: 34
# Predicted Rank 62: frc3494    (25p=48, 75p=64)   Actual Rank: 11
# Predicted Rank 62: frc4405    (25p=60, 75p=64)   Actual Rank: 58
# Predicted Rank 64: frc3172    (25p=61, 75p=67)   Actual Rank: 68
# Predicted Rank 68: frc6391    (25p=67, 75p=68)   Actual Rank: 66

# %%
display_monte_carlo_result(monte_carlo_event("2017carv", iterations=10), "2017carv")
# Out:
# Predicted Rank  1: frc2122    (25p= 1, 75p= 2)   Actual Rank: 3
# Predicted Rank  2: frc971     (25p= 2, 75p= 3)   Actual Rank: 2
# Predicted Rank  3: frc987     (25p= 2, 75p= 3)   Actual Rank: 5
# Predicted Rank  4: frc1690    (25p= 4, 75p= 5)   Actual Rank: 1
# Predicted Rank  5: frc3238    (25p= 5, 75p= 6)   Actual Rank: 6
# Predicted Rank  6: frc2974    (25p= 6, 75p= 7)   Actual Rank: 46
# Predicted Rank  7: frc4910    (25p= 6, 75p= 8)   Actual Rank: 33
# Predicted Rank  8: frc2992    (25p= 7, 75p=10)   Actual Rank: 21
# Predicted Rank  9: frc1700    (25p= 8, 75p=12)   Actual Rank: 30
# Predicted Rank 11: frc3339    (25p=10, 75p=12)   Actual Rank: 9
# Predicted Rank 12: frc2471    (25p=10, 75p=14)   Actual Rank: 26
# Predicted Rank 12: frc179     (25p=10, 75p=14)   Actual Rank: 14
# Predicted Rank 13: frc1937    (25p=10, 75p=15)   Actual Rank: 29
# Predicted Rank 13: frc3674    (25p=12, 75p=16)   Actual Rank: 23
# Predicted Rank 16: frc4334    (25p=14, 75p=28)   Actual Rank: 4
# Predicted Rank 17: frc2930    (25p=14, 75p=25)   Actual Rank: 8
# Predicted Rank 20: frc5293    (25p=18, 75p=27)   Actual Rank: 19
# Predicted Rank 24: frc5468    (25p=20, 75p=26)   Actual Rank: 12
# Predicted Rank 24: frc3196    (25p=20, 75p=31)   Actual Rank: 48
# Predicted Rank 24: frc1425    (25p=16, 75p=36)   Actual Rank: 16
# Predicted Rank 24: frc4911    (25p=19, 75p=40)   Actual Rank: 18
# Predicted Rank 28: frc4501    (25p=24, 75p=32)   Actual Rank: 37
# Predicted Rank 30: frc1577    (25p=20, 75p=42)   Actual Rank: 41
# Predicted Rank 30: frc2637    (25p=28, 75p=37)   Actual Rank: 38
# Predicted Rank 31: frc231     (25p=21, 75p=37)   Actual Rank: 11
# Predicted Rank 31: frc6530    (25p=24, 75p=40)   Actual Rank: 25
# Predicted Rank 32: frc2359    (25p=22, 75p=41)   Actual Rank: 15
# Predicted Rank 32: frc6502    (25p=28, 75p=45)   Actual Rank: 34
# Predicted Rank 32: frc4125    (25p=22, 75p=40)   Actual Rank: 52
# Predicted Rank 32: frc3802    (25p=26, 75p=44)   Actual Rank: 24
# Predicted Rank 33: frc6314    (25p=32, 75p=45)   Actual Rank: 54
# Predicted Rank 34: frc4990    (25p=23, 75p=42)   Actual Rank: 40
# Predicted Rank 36: frc6133    (25p=28, 75p=44)   Actual Rank: 56
# Predicted Rank 36: frc5511    (25p=30, 75p=46)   Actual Rank: 31
# Predicted Rank 37: frc3925    (25p=26, 75p=40)   Actual Rank: 13
# Predicted Rank 37: frc599     (25p=28, 75p=47)   Actual Rank: 39
# Predicted Rank 38: frc1671    (25p=26, 75p=50)   Actual Rank: 7
# Predicted Rank 38: frc3024    (25p=34, 75p=44)   Actual Rank: 36
# Predicted Rank 40: frc3490    (25p=28, 75p=49)   Actual Rank: 44
# Predicted Rank 40: frc2059    (25p=33, 75p=43)   Actual Rank: 20
# Predicted Rank 40: frc1746    (25p=38, 75p=45)   Actual Rank: 17
# Predicted Rank 41: frc3646    (25p=31, 75p=48)   Actual Rank: 61
# Predicted Rank 42: frc3128    (25p=34, 75p=54)   Actual Rank: 58
# Predicted Rank 42: frc1311    (25p=36, 75p=53)   Actual Rank: 66
# Predicted Rank 43: frc6704    (25p=38, 75p=48)   Actual Rank: 63
# Predicted Rank 44: frc4063    (25p=30, 75p=50)   Actual Rank: 10
# Predicted Rank 44: frc932     (25p=26, 75p=62)   Actual Rank: 22
# Predicted Rank 45: frc1648    (25p=29, 75p=53)   Actual Rank: 28
# Predicted Rank 45: frc2556    (25p=42, 75p=53)   Actual Rank: 35
# Predicted Rank 46: frc4091    (25p=38, 75p=54)   Actual Rank: 62
# Predicted Rank 47: frc5006    (25p=39, 75p=55)   Actual Rank: 67
# Predicted Rank 48: frc2557    (25p=44, 75p=57)   Actual Rank: 27
# Predicted Rank 48: frc6348    (25p=45, 75p=59)   Actual Rank: 47
# Predicted Rank 49: frc3035    (25p=40, 75p=56)   Actual Rank: 59
# Predicted Rank 49: frc3256    (25p=36, 75p=56)   Actual Rank: 51
# Predicted Rank 50: frc1266    (25p=33, 75p=56)   Actual Rank: 42
# Predicted Rank 52: frc5526    (25p=42, 75p=58)   Actual Rank: 57
# Predicted Rank 52: frc5607    (25p=50, 75p=61)   Actual Rank: 53
# Predicted Rank 56: frc1902    (25p=27, 75p=62)   Actual Rank: 64
# Predicted Rank 56: frc5985    (25p=48, 75p=63)   Actual Rank: 49
# Predicted Rank 56: frc6396    (25p=50, 75p=57)   Actual Rank: 60
# Predicted Rank 58: frc3648    (25p=50, 75p=66)   Actual Rank: 45
# Predicted Rank 61: frc6443    (25p=52, 75p=65)   Actual Rank: 43
# Predicted Rank 62: frc6414    (25p=61, 75p=65)   Actual Rank: 65
# Predicted Rank 63: frc3721    (25p=57, 75p=66)   Actual Rank: 32
# Predicted Rank 64: frc5627    (25p=60, 75p=64)   Actual Rank: 50
# Predicted Rank 64: frc6695    (25p=60, 75p=65)   Actual Rank: 55

# %%
display_monte_carlo_result(monte_carlo_event("2017hop", iterations=10), "2017hop")
# Out:
# Predicted Rank  1: frc604     (25p= 1, 75p= 2)   Actual Rank: 4
# Predicted Rank  2: frc2848    (25p= 2, 75p= 3)   Actual Rank: 8
# Predicted Rank  3: frc1619    (25p= 2, 75p= 3)   Actual Rank: 1
# Predicted Rank  4: frc1778    (25p= 3, 75p= 5)   Actual Rank: 9
# Predicted Rank  6: frc3309    (25p= 5, 75p= 7)   Actual Rank: 2
# Predicted Rank  8: frc3835    (25p= 5, 75p=10)   Actual Rank: 11
# Predicted Rank  8: frc4488    (25p= 7, 75p=14)   Actual Rank: 7
# Predicted Rank  8: frc4613    (25p= 6, 75p=11)   Actual Rank: 6
# Predicted Rank  8: frc2682    (25p= 8, 75p=14)   Actual Rank: 16
# Predicted Rank 10: frc4941    (25p= 7, 75p=12)   Actual Rank: 12
# Predicted Rank 10: frc5818    (25p= 9, 75p=14)   Actual Rank: 13
# Predicted Rank 11: frc3314    (25p=11, 75p=14)   Actual Rank: 3
# Predicted Rank 13: frc2903    (25p=10, 75p=17)   Actual Rank: 15
# Predicted Rank 15: frc6340    (25p=13, 75p=18)   Actual Rank: 14
# Predicted Rank 16: frc1868    (25p=11, 75p=21)   Actual Rank: 30
# Predicted Rank 16: frc2910    (25p=13, 75p=22)   Actual Rank: 20
# Predicted Rank 19: frc3132    (25p=17, 75p=28)   Actual Rank: 21
# Predicted Rank 20: frc5458    (25p=19, 75p=22)   Actual Rank: 10
# Predicted Rank 21: frc832     (25p=14, 75p=25)   Actual Rank: 5
# Predicted Rank 22: frc2383    (25p=20, 75p=26)   Actual Rank: 29
# Predicted Rank 24: frc4965    (25p=17, 75p=32)   Actual Rank: 18
# Predicted Rank 24: frc4513    (25p=21, 75p=34)   Actual Rank: 32
# Predicted Rank 24: frc5588    (25p=20, 75p=48)   Actual Rank: 19
# Predicted Rank 25: frc5429    (25p=23, 75p=32)   Actual Rank: 24
# Predicted Rank 26: frc5663    (25p=20, 75p=36)   Actual Rank: 40
# Predicted Rank 28: frc1319    (25p=24, 75p=31)   Actual Rank: 51
# Predicted Rank 28: frc5431    (25p=22, 75p=35)   Actual Rank: 22
# Predicted Rank 30: frc281     (25p=18, 75p=33)   Actual Rank: 41
# Predicted Rank 30: frc1744    (25p=27, 75p=37)   Actual Rank: 47
# Predicted Rank 30: frc4005    (25p=24, 75p=40)   Actual Rank: 26
# Predicted Rank 32: frc4401    (25p=28, 75p=42)   Actual Rank: 48
# Predicted Rank 33: frc6023    (25p=27, 75p=36)   Actual Rank: 38
# Predicted Rank 35: frc2230    (25p=33, 75p=38)   Actual Rank: 23
# Predicted Rank 36: frc1410    (25p=20, 75p=44)   Actual Rank: 27
# Predicted Rank 36: frc6517    (25p=31, 75p=43)   Actual Rank: 56
# Predicted Rank 37: frc4944    (25p=29, 75p=46)   Actual Rank: 17
# Predicted Rank 38: frc2587    (25p=31, 75p=45)   Actual Rank: 28
# Predicted Rank 38: frc6055    (25p=30, 75p=44)   Actual Rank: 36
# Predicted Rank 38: frc2996    (25p=32, 75p=53)   Actual Rank: 39
# Predicted Rank 40: frc2444    (25p=26, 75p=44)   Actual Rank: 50
# Predicted Rank 41: frc1836    (25p=33, 75p=48)   Actual Rank: 35
# Predicted Rank 41: frc4400    (25p=35, 75p=54)   Actual Rank: 25
# Predicted Rank 42: frc3931    (25p=38, 75p=45)   Actual Rank: 55
# Predicted Rank 44: frc4635    (25p=40, 75p=48)   Actual Rank: 33
# Predicted Rank 44: frc4915    (25p=34, 75p=53)   Actual Rank: 42
# Predicted Rank 45: frc1912    (25p=43, 75p=49)   Actual Rank: 54
# Predicted Rank 46: frc6366    (25p=34, 75p=52)   Actual Rank: 31
# Predicted Rank 46: frc2583    (25p=42, 75p=57)   Actual Rank: 34
# Predicted Rank 48: frc5887    (25p=39, 75p=52)   Actual Rank: 61
# Predicted Rank 48: frc5002    (25p=36, 75p=53)   Actual Rank: 66
# Predicted Rank 50: frc6305    (25p=46, 75p=55)   Actual Rank: 59
# Predicted Rank 50: frc3039    (25p=47, 75p=52)   Actual Rank: 49
# Predicted Rank 52: frc5737    (25p=44, 75p=59)   Actual Rank: 60
# Predicted Rank 53: frc5496    (25p=46, 75p=61)   Actual Rank: 43
# Predicted Rank 54: frc2543    (25p=50, 75p=57)   Actual Rank: 53
# Predicted Rank 56: frc6434    (25p=47, 75p=61)   Actual Rank: 44
# Predicted Rank 58: frc114     (25p=51, 75p=61)   Actual Rank: 37
# Predicted Rank 58: frc4403    (25p=49, 75p=62)   Actual Rank: 52
# Predicted Rank 58: frc2896    (25p=48, 75p=62)   Actual Rank: 57
# Predicted Rank 58: frc6442    (25p=56, 75p=64)   Actual Rank: 65
# Predicted Rank 59: frc5454    (25p=54, 75p=65)   Actual Rank: 63
# Predicted Rank 60: frc5516    (25p=51, 75p=61)   Actual Rank: 45
# Predicted Rank 60: frc5705    (25p=53, 75p=67)   Actual Rank: 67
# Predicted Rank 60: frc3562    (25p=54, 75p=63)   Actual Rank: 46
# Predicted Rank 62: frc2950    (25p=58, 75p=63)   Actual Rank: 62
# Predicted Rank 63: frc6429    (25p=60, 75p=65)   Actual Rank: 58
# Predicted Rank 65: frc6754    (25p=61, 75p=66)   Actual Rank: 64

# %%
display_monte_carlo_result(monte_carlo_event("2017tes", iterations=10), "2017tes")
# Out:
# Predicted Rank  1: frc148     (25p= 1, 75p= 2)   Actual Rank: 4
# Predicted Rank  4: frc3464    (25p= 2, 75p= 8)   Actual Rank: 19
# Predicted Rank  5: frc2168    (25p= 2, 75p= 8)   Actual Rank: 3
# Predicted Rank  6: frc3452    (25p= 3, 75p=12)   Actual Rank: 5
# Predicted Rank  6: frc95      (25p= 4, 75p=12)   Actual Rank: 25
# Predicted Rank  6: frc469     (25p= 4, 75p=14)   Actual Rank: 1
# Predicted Rank  8: frc2084    (25p= 5, 75p=11)   Actual Rank: 17
# Predicted Rank  8: frc6538    (25p= 6, 75p=10)   Actual Rank: 8
# Predicted Rank  8: frc3130    (25p= 6, 75p=12)   Actual Rank: 10
# Predicted Rank  9: frc2607    (25p= 7, 75p=17)   Actual Rank: 26
# Predicted Rank 10: frc3683    (25p= 6, 75p=16)   Actual Rank: 12
# Predicted Rank 11: frc3015    (25p= 6, 75p=14)   Actual Rank: 11
# Predicted Rank 12: frc2619    (25p=10, 75p=14)   Actual Rank: 7
# Predicted Rank 12: frc829     (25p= 9, 75p=14)   Actual Rank: 2
# Predicted Rank 14: frc1519    (25p=10, 75p=19)   Actual Rank: 9
# Predicted Rank 14: frc193     (25p=13, 75p=16)   Actual Rank: 34
# Predicted Rank 18: frc3546    (25p=10, 75p=21)   Actual Rank: 50
# Predicted Rank 19: frc3974    (25p=16, 75p=25)   Actual Rank: 24
# Predicted Rank 20: frc834     (25p=19, 75p=24)   Actual Rank: 15
# Predicted Rank 22: frc3419    (25p=18, 75p=26)   Actual Rank: 6
# Predicted Rank 22: frc190     (25p=16, 75p=26)   Actual Rank: 13
# Predicted Rank 22: frc4485    (25p=17, 75p=37)   Actual Rank: 20
# Predicted Rank 24: frc2386    (25p=18, 75p=26)   Actual Rank: 14
# Predicted Rank 24: frc1706    (25p=18, 75p=33)   Actual Rank: 40
# Predicted Rank 26: frc2537    (25p=22, 75p=28)   Actual Rank: 27
# Predicted Rank 26: frc292     (25p=24, 75p=36)   Actual Rank: 58
# Predicted Rank 26: frc51      (25p=22, 75p=31)   Actual Rank: 44
# Predicted Rank 28: frc4508    (25p=24, 75p=32)   Actual Rank: 33
# Predicted Rank 29: frc11      (25p=26, 75p=40)   Actual Rank: 46
# Predicted Rank 31: frc4481    (25p=28, 75p=43)   Actual Rank: 30
# Predicted Rank 32: frc272     (25p=30, 75p=46)   Actual Rank: 52
# Predicted Rank 34: frc5422    (25p=34, 75p=48)   Actual Rank: 31
# Predicted Rank 35: frc1781    (25p=31, 75p=39)   Actual Rank: 42
# Predicted Rank 35: frc3414    (25p=28, 75p=46)   Actual Rank: 60
# Predicted Rank 36: frc191     (25p=26, 75p=40)   Actual Rank: 41
# Predicted Rank 37: frc1391    (25p=35, 75p=50)   Actual Rank: 35
# Predicted Rank 38: frc772     (25p=34, 75p=43)   Actual Rank: 45
# Predicted Rank 38: frc3359    (25p=31, 75p=46)   Actual Rank: 23
# Predicted Rank 40: frc4991    (25p=32, 75p=50)   Actual Rank: 62
# Predicted Rank 42: frc1792    (25p=38, 75p=48)   Actual Rank: 51
# Predicted Rank 42: frc714     (25p=40, 75p=49)   Actual Rank: 61
# Predicted Rank 42: frc2039    (25p=34, 75p=54)   Actual Rank: 22
# Predicted Rank 43: frc3547    (25p=35, 75p=46)   Actual Rank: 32
# Predicted Rank 44: frc111     (25p=40, 75p=50)   Actual Rank: 21
# Predicted Rank 45: frc6582    (25p=40, 75p=51)   Actual Rank: 18
# Predicted Rank 45: frc3284    (25p=38, 75p=53)   Actual Rank: 28
# Predicted Rank 46: frc1939    (25p=37, 75p=50)   Actual Rank: 47
# Predicted Rank 46: frc1023    (25p=40, 75p=51)   Actual Rank: 16
# Predicted Rank 46: frc2177    (25p=42, 75p=51)   Actual Rank: 48
# Predicted Rank 46: frc4506    (25p=37, 75p=55)   Actual Rank: 37
# Predicted Rank 46: frc4342    (25p=33, 75p=50)   Actual Rank: 53
# Predicted Rank 48: frc6419    (25p=40, 75p=55)   Actual Rank: 65
# Predicted Rank 48: frc3201    (25p=45, 75p=58)   Actual Rank: 39
# Predicted Rank 52: frc5016    (25p=48, 75p=55)   Actual Rank: 29
# Predicted Rank 53: frc5528    (25p=42, 75p=60)   Actual Rank: 49
# Predicted Rank 55: frc4356    (25p=49, 75p=60)   Actual Rank: 55
# Predicted Rank 56: frc2783    (25p=52, 75p=60)   Actual Rank: 54
# Predicted Rank 56: frc3525    (25p=54, 75p=66)   Actual Rank: 67
# Predicted Rank 57: frc5952    (25p=53, 75p=59)   Actual Rank: 56
# Predicted Rank 58: frc3954    (25p=54, 75p=63)   Actual Rank: 38
# Predicted Rank 60: frc2851    (25p=48, 75p=61)   Actual Rank: 36
# Predicted Rank 60: frc6637    (25p=57, 75p=61)   Actual Rank: 43
# Predicted Rank 60: frc6622    (25p=54, 75p=64)   Actual Rank: 59
# Predicted Rank 63: frc4241    (25p=60, 75p=64)   Actual Rank: 68
# Predicted Rank 64: frc1985    (25p=61, 75p=66)   Actual Rank: 64
# Predicted Rank 65: frc271     (25p=54, 75p=66)   Actual Rank: 57
# Predicted Rank 65: frc4607    (25p=64, 75p=68)   Actual Rank: 63
# Predicted Rank 66: frc2068    (25p=62, 75p=68)   Actual Rank: 66
