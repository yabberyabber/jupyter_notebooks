# %%
import itertools

MAX_SALES = 4
STOCK_PRICES = [1, 3, 2, 9, 2, 4, 6, 76, 87, 78, 65, 43,23, 322,3 , 43, 65, 76, 87]

partialSolutions = []

class PartialSolution():
    def __init__(self, known_sales, next_sale=None):
        self.known_sales = known_sales[::]
        if next_sale:
            self.known_sales.append(next_sale)
        self.value = self.calc_value()
        
    def enumerate_children(self):
        used_dates = set(itertools.chain.from_iterable(self.known_sales))
        
        largest_buy_date = max(list([sale[0] for sale in self.known_sales]) + [-1])
        hidden_buy_dates = set(range(largest_buy_date + 1))
        
        free_dates = set(range(len(STOCK_PRICES))) - used_dates - hidden_buy_dates
        free_dates = sorted(list(free_dates))
        
        
        for buy_date in free_dates[:-1]:
            for sell_date in free_dates:
                if sell_date > buy_date:
                    yield (buy_date, sell_date)
    
    def calc_value(self):
        value = 0
        for buy_date, sell_date in self.known_sales:
            value += STOCK_PRICES[sell_date] - STOCK_PRICES[buy_date]
        return value
    
    def num_sales(self):
        return len(self.known_sales)

value_maximum = 0
value_maximizer = PartialSolution([])

partialSolutions.append(value_maximizer)

while partialSolutions:
    sol = partialSolutions.pop()
    if sol.num_sales() >= MAX_SALES:
        continue
    
    for next_sale in sol.enumerate_children():
        next_child = PartialSolution(sol.known_sales, next_sale)
        if next_child.value > value_maximum:
            print("New max: ", next_child.value, " -> ", next_child.known_sales)
            value_maximum = next_child.value
            value_maximizer = next_child
        partialSolutions.append(next_child)
# Out:
# New max:  2  ->  [(0, 1)]
# New max:  8  ->  [(0, 3)]
# New max:  75  ->  [(0, 7)]
# New max:  86  ->  [(0, 8)]
# New max:  321  ->  [(0, 13)]
# New max:  339  ->  [(12, 13), (14, 15)]
# New max:  361  ->  [(12, 13), (14, 16)]
# New max:  372  ->  [(12, 13), (14, 17)]
# New max:  383  ->  [(12, 13), (14, 18)]
# New max:  405  ->  [(12, 13), (14, 18), (15, 16)]
# New max:  416  ->  [(12, 13), (14, 18), (15, 17)]
# New max:  438  ->  [(11, 18), (12, 13), (14, 17), (15, 16)]
# New max:  442  ->  [(6, 18), (12, 13), (14, 16)]
# New max:  453  ->  [(6, 18), (12, 13), (14, 17)]
# New max:  475  ->  [(6, 18), (12, 13), (14, 17), (15, 16)]
# New max:  477  ->  [(6, 9), (12, 13), (14, 18), (15, 16)]
# New max:  488  ->  [(6, 9), (12, 13), (14, 18), (15, 17)]
# New max:  497  ->  [(6, 8), (12, 13), (14, 18), (15, 17)]
# New max:  514  ->  [(5, 18), (6, 17), (12, 13), (14, 16)]
# New max:  516  ->  [(5, 18), (6, 9), (12, 13), (14, 16)]
# New max:  527  ->  [(5, 18), (6, 9), (12, 13), (14, 17)]
# New max:  536  ->  [(5, 18), (6, 8), (12, 13), (14, 17)]
# New max:  538  ->  [(5, 9), (6, 8), (12, 13), (14, 18)]
# New max:  548  ->  [(4, 18), (5, 13), (6, 9), (14, 17)]
# New max:  557  ->  [(4, 18), (5, 13), (6, 8), (14, 17)]
# New max:  559  ->  [(4, 13), (5, 9), (6, 8), (14, 18)]
# New max:  560  ->  [(2, 18), (4, 13), (5, 9), (6, 8)]
# New max:  561  ->  [(2, 18), (4, 13), (5, 8), (14, 17)]
# New max:  563  ->  [(2, 13), (4, 9), (5, 8), (14, 18)]
# New max:  564  ->  [(1, 13), (2, 9), (4, 8), (14, 18)]
# New max:  565  ->  [(0, 18), (2, 13), (4, 9), (5, 8)]
# New max:  566  ->  [(0, 18), (1, 13), (2, 9), (4, 8)]
